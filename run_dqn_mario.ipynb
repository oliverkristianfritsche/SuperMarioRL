# %%
import torch

# %%
from agents.DQNagent import *
from agents.PPOagent import *
from gameboy_env import *
import sys
sys.path.append('models')
from models.dqn import *
# Out:
# UserWarning: Using SDL2 binaries from pysdl2-dll 2.30.0

# %%
print(torch.cuda.is_available())
env = MarioGameBoyEnv("roms/Super Mario Land (JUE) (V1.1) [!].gb",observation_shape=(84,84), window_type="human")
# Configuration with the game name and hyperparameters
game_name = "SuperMarioLand"
config = Config(
    game_name=game_name,
    env=env,
    model_function=DQN,
    target_model_function=DQN,
    replay_buffer_size=1000000,  # Optional, showing default value as an example
    gamma=0.9999999,  # Optional, showing default value as an example
    batch_size=32,
    epsilon_decay=.999,  # Optional, showing default value as an example
    epsilon_decay_frames=1000000,  # Optional, showing default value as an example
    epsilon_min=0.1,  # Optional, showing default value as an example
    epsilon=1,
    state_preprocessing_fn=None,  # Assuming a default value; define if needed
    update_target_every=50,
    save_model_every=100,
    n_ticks_to_skip=0,
    epsilon_decay_rate_adjustment=1  # Optional, showing default value as an example
)
# Initialize the DQN Agent
agent = DQNAgent(config)
# Out:
# True
# Observation shape: (84, 84)
# No training history found, starting from scratch.
# c:\Users\saile\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# No checkpoint found for prefix 'model', starting from scratch.
# No checkpoint found for prefix 'target_model', starting from scratch.

# %%
agent.train(1000000)
# Out:
# Episode: 5, Total reward: -0.054554100313086495, Epsilon: 0.9917443000002718, Time Steps: 7506, Gamma: 0.5403600336266278
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agent.train(1000000)
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:288, in DQNAgent.train(self, num_episodes, reward_discount_factor, discount_step_interval)
#     286 while not done:
#     287     action = self.act(state)
# --> 288     next_state, reward, done, _ = self.config.env.step(action)
#     289     self.time_steps += 1 * self.config.env.n_ticks_per_step
#     290     total_frames += 1
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\gameboy_env.py:146, in step(self, action)
#     143 elif done and self.time_steps < self.max_steps:
#     144     reward -= 1 * self.death_scalar
# --> 146 for _ in range(self.n_ticks_per_step):
#     147     self.time_steps += 1
#     148     self.pyboy.tick()
#
# KeyboardInterrupt:

# %%
import torch

# %%
from agents.DQNagent import *
from agents.PPOagent import *
from gameboy_env import *
import sys
sys.path.append('models')
from models.dqn import *
# Out:
# UserWarning: Using SDL2 binaries from pysdl2-dll 2.30.0

# %%
print(torch.cuda.is_available())
env = GameBoyEnv("roms/Super Mario Land (JUE) (V1.1) [!].gb",observation_shape=(84,84), window_type="human")
config = Config(env,EncoderWithHead,EncoderWithHead, checkpoint_subfolder="limited_rom_encoder", epsilon=1)
agent = DQNAgent(config)#config,model,target_model

agent.train(7500,discount_step_interval=500)  # Train for 7500 episodes
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 config = Config(env,EncoderWithHead,EncoderWithHead, checkpoint_subfolder="limited_rom_encoder", epsilon=1)
#       4 agent = DQNAgent(config)#config,model,target_model
# ----> 6 agent.train(7500)  # Train for 7500 episodes
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:145, in DQNAgent.train(self, num_episodes, reward_discount_factor, discount_step_interval)
#     143 reward = reward*self.temp_gamma
#     144 self.replay_buffer.push(state.transpose(2,0,1), action, reward, next_state.transpose(2,0,1), done)
# --> 145 self.update()
#     146 state = next_state
#     148 if reward>100:
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:98, in DQNAgent.update(self)
#      95 state, action, reward, next_state, done = self.replay_buffer.sample(self.config.batch_size)
#      97 state = torch.FloatTensor(state).to(self.device)
# ---> 98 next_state = torch.FloatTensor(next_state).to(self.device)
#      99 action = torch.LongTensor(action).unsqueeze(-1).to(self.device)  # Ensure correct shape [batch_size, 1]
#     100 reward = torch.FloatTensor(reward).to(self.device)
#
# KeyboardInterrupt:

# %%
import torch

# %%
from agents.DQNagent import *
from agents.PPOagent import *
from gameboy_env import *
import sys
sys.path.append('models')
from models.dqn import *
# Out:
# UserWarning: Using SDL2 binaries from pysdl2-dll 2.30.0

# %%
print(torch.cuda.is_available())
env = GameBoyEnv("roms/Super Mario Land (JUE) (V1.1) [!].gb",observation_shape=(84,84), window_type="human")
config = Config(env,DQN,DQN, checkpoint_subfolder="limited_rom_encoder_3dof_lineardecay_bs32", epsilon=.92,batch_size=32,n_ticks_to_skip=3)
agent = DQNAgent(config)#config,model,target_model

agent.train(7500,discount_step_interval=300,reward_discount_factor=.989)  # Train for 7500 episodes
# Out:
# Episode: 90, Total reward: 2.0, Epsilon: 0.920798124999301, Time Steps: 1004, Gamma: 0.9673615722638331
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 config = Config(env,DQN,DQN, checkpoint_subfolder="limited_rom_encoder_3dof_lineardecay_bs32", epsilon=.975,batch_size=32,n_ticks_to_skip=3)
#       4 agent = DQNAgent(config)#config,model,target_model
# ----> 6 agent.train(7500,discount_step_interval=300,reward_discount_factor=.989)  # Train for 7500 episodes
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:258, in DQNAgent.train(self, num_episodes, reward_discount_factor, discount_step_interval)
#     256 adjusted_reward = reward * self.temp_gamma
#     257 self.replay_buffer.push(state.transpose(2, 0, 1), action, adjusted_reward, next_state.transpose(2, 0, 1), done)
# --> 258 self.update()
#     259 state = next_state
#     262 total_reward += reward
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:202, in DQNAgent.update(self)
#     199 state, action, reward, next_state, done = self.replay_buffer.sample(self.config.batch_size)
#     201 state = torch.FloatTensor(state).to(self.device)
# --> 202 next_state = torch.FloatTensor(next_state).to(self.device)
#     203 action = torch.LongTensor(action).unsqueeze(-1).to(self.device)  # Ensure correct shape [batch_size, 1]
#     204 reward = torch.FloatTensor(reward).to(self.device)
#
# KeyboardInterrupt:

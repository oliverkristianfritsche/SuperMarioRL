# %%
import torch

# %%
from agents.DQNagent import *
from agents.PPOagent import *
from gameboy_env import *
import sys
sys.path.append('models')
from models.dqn import *
# Out:
# UserWarning: Using SDL2 binaries from pysdl2-dll 2.30.0

# %%
print(torch.cuda.is_available())
env = GameBoyEnv("roms/Super Mario Land (JUE) (V1.1) [!].gb",observation_shape=(84,84), window_type="human")
config = Config(env,DQN,DQN, checkpoint_subfolder="limited_rom_encoder_3dof_lineardecay_bs32", epsilon=1,batch_size=32,n_ticks_to_skip=3,update_target_every=50,save_model_every=100)
agent = DQNAgent(config)#config,model,target_model

agent.train(7500,discount_step_interval=300,reward_discount_factor=.95)  # Train for 7500 episodes
# Out:
# Episode: 701, Total reward: -7.0, Epsilon: 0.22275054998006272, Time Steps: 6788, Gamma: 0.32353351262035446
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 config = Config(env,DQN,DQN, checkpoint_subfolder="limited_rom_encoder_3dof_lineardecay_bs32", epsilon=1,batch_size=32,n_ticks_to_skip=3,update_target_every=50)
#       4 agent = DQNAgent(config)#config,model,target_model
# ----> 6 agent.train(7500,discount_step_interval=300,reward_discount_factor=.95)  # Train for 7500 episodes
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:269, in DQNAgent.train(self, num_episodes, reward_discount_factor, discount_step_interval)
#     267 adjusted_reward = reward * self.temp_gamma
#     268 self.replay_buffer.push(state.transpose(2, 0, 1), action, adjusted_reward, next_state.transpose(2, 0, 1), done)
# --> 269 self.update()
#     270 state = next_state
#     273 total_reward += reward
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:211, in DQNAgent.update(self)
#     208     return
#     209 state, action, reward, next_state, done = self.replay_buffer.sample(self.config.batch_size)
# --> 211 state = torch.FloatTensor(state).to(self.device)
#     212 next_state = torch.FloatTensor(next_state).to(self.device)
#     213 action = torch.LongTensor(action).unsqueeze(-1).to(self.device)  # Ensure correct shape [batch_size, 1]
#
# KeyboardInterrupt:

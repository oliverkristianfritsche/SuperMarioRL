# %%
import torch

# %%
from agents.DQNagent import *
from agents.PPOagent import *
from gameboy_env import *
import sys
sys.path.append('models')
from models.dqn import *

# %%
print(torch.cuda.is_available())
env = GameBoyEnv("roms/Super Mario Land (JUE) (V1.1) [!].gb",observation_shape=(84,84), window_type="human")
config = Config(env,DQN,DQN, checkpoint_subfolder="limited_rom_encoder_4dof_lineardecay_bs32_rdf95", epsilon=1,batch_size=32,n_ticks_to_skip=3,update_target_every=50,save_model_every=100)
agent = DQNAgent(config)#config,model,target_model
# Out:
# True
# Observation shape: (84, 84)
# No training history found, starting from scratch.
# c:\Users\saile\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# No checkpoint found for prefix 'model', starting from scratch.
# No checkpoint found for prefix 'target_model', starting from scratch.

# %%
agent.train(7500,discount_step_interval=300,reward_discount_factor=.95)  # Train for 7500 episodes
# Out:
# Episode: 13, Total reward: -10.0, Epsilon: 0.9566344000014277, Time Steps: 581, Gamma: 0.949999905
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agent.train(7500,discount_step_interval=300,reward_discount_factor=.95)  # Train for 7500 episodes
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:276, in DQNAgent.train(self, num_episodes, reward_discount_factor, discount_step_interval)
#     274 adjusted_reward = (reward * self.temp_gamma) + (-self.config.env.death_scalar * (1 - self.temp_gamma))
#     275 self.replay_buffer.push(state.transpose(2, 0, 1), action, adjusted_reward, next_state.transpose(2, 0, 1), done)
# --> 276 self.update()
#     277 state = next_state
#     280 total_reward += reward
#
# File b:\SharedFolder\Projects\SoftwareProjects\SuperMarioRL\agents\DQNagent.py:213, in DQNAgent.update(self)
# ...
